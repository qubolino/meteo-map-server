# %%
import urllib.request
from datetime import datetime, timedelta

# Example: Download TEMSI map for May 9, 2026, 12 UTC
date = datetime(2026, 5, 9)
hour = 12
url = f"https://aviation.meteo.fr/aeroweb/data/temsi/FRANCE/{date.strftime('%Y%m%d')}{hour:02d}00.png"
filename = f"temsi_france_{date.strftime('%Y%m%d')}_{hour:02d}00.png"

https://aviation.meteo.fr//FR/aviation/affiche_image.php?login=fampsLSMuYmAdrAK4GqcZ2xnlmZoYGrd1uE%3D&layer=sigwx/fr/france&echeance=20260511120000

https://sofia-briefing.aviation-civile.gouv.fr/sofia/pages/meteotemsi.html

<a target="_blank" href="https://aviation.meteo.fr//FR/aviation/affiche_image.php?login=fampsLSMuYmAdrAK4GqcZ2xnmGlhY23d1uE%3D&amp;layer=sigwx/fr/france&amp;echeance=20260511180000">TEMSI-FL20-150-FRANCE-18 UTC</a>

try:
    urllib.request.urlretrieve(url, filename)
    print(f"Downloaded: {filename}")
except Exception as e:
    print(f"Failed to download: {e}")
    print("Check if the URL is correct or if authentication is required.")
# Out:
# Failed to download: HTTP Error 404: Not Found
# Check if the URL is correct or if authentication is required.
